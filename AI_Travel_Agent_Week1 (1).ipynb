# %%
# !pip install openai
# !pip install requests
# !pip install python-dotenv

# %%
from getpass import getpass
import os

os.environ["GROQ_API_KEY"] = getpass("Enter your Groq API key: ")
os.environ["WEATHERSTACK_API_KEY"] = getpass("Enter your Weatherstack API key: ")
# Out:
# Enter your Groq API key: ··········
# Enter your Weatherstack API key: ··········

# %%
import requests
import os

def get_weather(city):
    api_key = os.environ.get("WEATHERSTACK_API_KEY")

    if not api_key:
        return "Weather API key not set!"

    url = f"http://api.weatherstack.com/current?access_key={api_key}&query={city}"

    response = requests.get(url)
    data = response.json()

    print("Status Code:", response.status_code)
    print("Response:", data)

    if "current" in data:
        temp = data["current"]["temperature"]
        condition = data["current"]["weather_descriptions"][0]
        return f"The temperature in {city} is {temp}°C with {condition}."
    else:
        return "Could not fetch weather data."

# %%
get_weather("Hyderabad")
# Out:
# Status Code: 200
# ...

# %%
def mock_llm(user_input):
    if "goa" in user_input.lower():
        return "For a 2-day trip to Goa, visit Baga Beach, Fort Aguada, and enjoy local seafood."
    elif "kerala" in user_input.lower():
        return "For Kerala, explore Munnar, Alleppey houseboats, and Kochi."
    else:
        return "I can help you plan trips or check weather."

# %%
def travel_agent(user_input):
    if "weather" in user_input.lower():
        city = user_input.split("in")[-1].strip()
        return get_weather(city)
    else:
        return mock_llm(user_input)

# %%
travel_agent("What is the weather in Hyderabad?")
travel_agent("Suggest a 2-day trip to Goa")
# Out:
# Status Code: 200
# ...

# %%
import requests

def get_weather(city):
    api_key ="51d46d583ebcacd7053089da36812ffa"

    url = "http://api.weatherstack.com/current"

    params = {
        "access_key": api_key,
        "query": city
    }

    response = requests.get(url, params=params)
    data = response.json()

    # Debug print
    print("API Response:", data)

    if "error" in data:
        return f"Error: {data['error']['info']}"

    temperature = data["current"]["temperature"]
    description = data["current"]["weather_descriptions"][0]

    return f"🌤 {temperature}°C, {description}"

# %%
travel_agent("What is the weather in Hyderabad?")
travel_agent("Suggest a 2-day trip to Goa")
# Out:
# API Response: {'request': {'type': 'City', 'query': 'Hyderabad, India', 'language': 'en', 'unit': 'm'}, 'location': {'name': 'Hyderabad', 'country': 'India', 'region': 'Telangana', 'lat': '17.375', 'lon': '78.474', 'timezone_id': 'Asia/Kolkata', 'localtime': '2026-03-01 19:36', 'localtime_epoch': 1772393760, 'utc_offset': '5.50'}, 'current': {'observation_time': '02:06 PM', 'temperature': 29, 'weather_code': 116, 'weather_icons': ['https://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'], 'weather_descriptions': ['Partly cloudy'], 'astro': {'sunrise': '06:34 AM', 'sunset': '06:22 PM', 'moonrise': '04:30 PM', 'moonset': '04:55 AM', 'moon_phase': 'Waxing Gibbous', 'moon_illumination': 93}, 'air_quality': {'co': '319.85', 'no2': '2.75', 'o3': '155', 'so2': '6.35', 'pm2_5': '36.55', 'pm10': '37.25', 'us-epa-index': '2', 'gb-defra-index': '2'}, 'wind_speed': 4, 'wind_degree': 243, 'wind_dir': 'WSW', 'pressure': 1012, 'precip': 0, 'humidity': 52, 'clou
# ...

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai

genai.configure(api_key="AIzaSyBE26QTBIDxclK8IRuwrRAyJT_5UXETo_Q")

# Consider checking available models with genai.list_models()
# and try a commonly available model like 'gemini-pro' if 'gemini-1.5-flash' is causing issues.
model = genai.GenerativeModel("gemini-pro-latest")

# %%
def travel_agent(user_input):
    if "weather" in user_input.lower():
        city = user_input.split("in")[-1].strip()
        print("Extracted city:", city)   # 👈 debug
        return get_weather(city)
    else:
        return groq_llm(user_input)

# %%
# !pip install -q groq
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 8.3 MB/s eta 0:00:00

# %%
from groq import Groq

client = Groq(api_key="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")

# %%
def groq_llm(user_input):
    chat_completion = client.chat.completions.create(
        messages=[
            {"role": "user", "content": user_input}
        ],
        model="llama3-70b-8192"
    )

    return chat_completion.choices[0].message.content

# %%
from groq import Groq
import os

client = Groq(api_key="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")

def groq_llm(prompt):
    response = client.chat.completions.create(
        model="llama-3.1-8b-instant",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content

print(groq_llm("Suggest a 2-day trip to Goa"))
# Out:
# Goa, a tropical paradise known for its stunning beaches, vibrant culture, and rich history. Here's a suggested 2-day itinerary for a trip to Goa:
#
# **Day 1:**
#
# 1. **Morning:**
# - Start the day with a delicious breakfast at a local café in Panjim, the capital city of Goa.
# - Visit **Miramar Beach**, a scenic beach with a beautiful view of the Arabian Sea.
# - Take a leisurely walk along the beach and enjoy the fresh air and sound of the waves.
#
# 2. **Mid-morning:**
# - Visit the **Basilica of Bom Jesus**, a UNESCO World Heritage Site, to admire its stunning architecture and rich history.
# - Explore the nearby **Se Cathedral**, one of the largest cathedrals in Asia and another UNESCO World Heritage Site.
#
# 3. **Lunch:**
# - Head to a local restaurant in Panjim to enjoy some authentic Goan cuisine, such as prawn curry or fish fry.
#
# 4. **Afternoon:**
# - Visit **Fort Aguada**, a 17th-century fort located on a hillock in Candolim.
# ...

# %%
print(travel_agent("Plan a 3-day trip to Kerala"))
print(travel_agent("Weather in Hyderabad"))
# Out:
# **3-Day Trip to Kerala Itinerary**
#
# **Day 1: Arrival and Exploration of Cochin**
#
# - **Morning:** Arrive at Cochin International Airport and check into your hotel.
# - **9:00 am:** Visit the Mattancherry Palace, a 16th-century Portuguese palace which is known for its beautiful murals and Portuguese architecture.
# - **11:00 am:** Visit the St. Francis Church, where Vasco da Gama is buried. It's a beautiful example of the architecture of early Portuguese colonial rule.
# - **1:00 pm:** Take a break for lunch and try some local Keralite cuisine like fish fry, sadya, or traditional Keralite dishes.
# - **3:00 pm:** Visit the Chinese Fishing Nets at Fort Kochi, a popular spot for shopping and photo opportunities.
# - **6:00 pm:** Enjoy the sunset at the beach or explore the local markets for souvenirs.
# - **8:00 pm:** Try some local cuisine and enjoy the night life in Cochin.
#
# **Day 2: Periyar Wildlife Sanctuary**
#
# ...
